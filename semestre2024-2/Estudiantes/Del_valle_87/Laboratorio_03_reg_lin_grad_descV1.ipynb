# %% [markdown]
# <a href="https://colab.research.google.com/github/CienciaDatosUdea/002_EstudiantesAprendizajeEstadistico/blob/main/semestre2024-2/Laboratorios/Laboratorio_03_reg_lin_grad_descV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 03:
# **Por: Juliana del valle**

# %% [markdown]
# # Laboratorio 03
#
#
# 1. Supongamos que un conjunto de características y datos etiquetados estan dados de la siguiente manera:
#
# Crear un data frame de pandas con los siguientes datos:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|
#
#
#
#
# 2. Crear una función para calcular la función de coste.
#
# 3. Asumiendo que $\theta_0=0$, represente gráficamente la función de costo para diferentes valores de $\theta_1$. Determine el valor mínimo de la función de costo y, con este valor, grafique la ecuación de regresión obtenida sobre los datos del dataframe que ha construido.
#
#
#
# 4. Suponiendo ahora que los datos de entrenamiento viene dados de la siguiente manera:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|
#
# Encontrar la función de coste para diferentes valores de $\theta_0$, $\theta_1$.
# Para ello puede emplear los metodos `surface` y `contour` dentro de la libreria de `matplotlib`.  Construya primero, con los valores de $\theta_0$, $\theta_1 $ definidos un `np.meshgrid` y evalue  para cada punto $\theta_0$, $\theta_1$ la función de coste.
#
# Para el gráfico 3D puede emplear algo similar a las siguientes lineas de código
#
# ```
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.plot_surface(t0, t1, J )
# ax.contour(t0, t1, J, 200,   linestyles="solid")
# ax.set_xlabel("$\\theta_0$")
# ax.set_ylabel("$\\theta_1$")
# plt.show()
# ```
#
#
# En los casos anteriores la solución solo involucra 1 y 2 parámetros para la representación de la función de coste en  2D y 3D respectivamente. Cuando se tienen más parametros a optmizar, no podemos tener una representacion gráfica, análoga a los casos anteriores. Notese además que los datos anteriores no tiene ningún ruido y solo se esta realizados  de esta manera, por motivos didácticos.
#
# 5. Encontrar la expresión teórica para la función de coste en el caso 1D y 2D.

# %% [markdown]
# # Gradiente Descendente
#
#
# Para determinar el mínimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
#
# - Proponer un número aleatorios inicial $\omega_i$
# - Para descender al mínimo de la función, encontremos un  valor para el cual
# el deriva de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# - Evaluar $f(\omega_{i+1})$
#
# - Iterar hasta encontrar el mínimo de la función
#
#
# 6. Construya un algoritmo en el que emplee el gradiente descente para determinar el minimo de una función, determine el mínimo con una error epsilon de  1E-4, pruebe su algoritmo para $f(x)= (x-4)^2$ y al menos 3 valores de $\alpha$
#
#
# 7. Para responder este punto puede consultar la siguiente  página y seguir el video[Ejemplo guia: dotcsv](https://www.youtube.com/watch?v=-_A_AAxqzCg):
#
# Encontrar el mínimo de la siguiente función a través del metodo del gradiente descendente https://en.wikipedia.org/wiki/Gradient_descent:
#
#
# \begin{equation}
# F(x,y) = \sin \left( \frac{1}{2}x^2-\frac{1}{4}y^2 +3\right) \cos (2x+1-e^y)
# \end{equation}
#
#   -  Para ello realice una gráfica de la función en 3D, y un mapa de contorno de la función.
#   - Determine el valor mínimo de la función con el metodo del gradiente descendente.

# %% [markdown]
# # Modelo de *machine learning*: Solución general
#
# Un modelo general para solucionar un problema de machinine learning puede ser estructurado como sigue:
#
#
# a. Eliger el modelo a emplear:
# \begin{equation}
# h(X,\Theta)
# \end{equation}
#
# - En el caso de una regresion lineal tenemos que $h(X,\Theta=(\theta_0, \theta_1))$:
#
#     \begin{equation}
#     h(X) = (\theta_0 + \theta_1 X)
#     \end{equation}
#
#
# b. Eligir la funcion de coste :
# -  Metrica Ecuclidiana:
# \begin{equation}
# J(\Theta)=\frac{1}{2m} \sum_{i=1}^m ( h_{\theta} (X^{(i)})-y^{(i)})^2
# \end{equation}
# - [Lista de funciones de coste que pueden ser empleadas](https://jmlb.github.io/flashcards/2018/04/21/list_cost_functions_fo_neuralnets/)
#
#
# c. Aplicar el gradiente descendente iterativamente, hasta encontrar el minimo:
#
# \begin{equation}
# \Delta \vec{\Theta} =  - \alpha \nabla J(\Theta)
# \end{equation}
#
#
#
# - En el caso de una regresion lineal tenemos que $h(X,\Theta=(\theta_0, \theta_1))$:
#
#
# \begin{equation}
# \theta_0 := \theta_0 - \alpha \frac{\partial J}{\partial \theta_0}
# \end{equation}
#
# \begin{equation}
# \theta_1 := \theta_1 - \alpha \frac{\partial J}{\partial \theta_1}
# \end{equation}

# %% [markdown]
# 8. Empleando los siguientes datos :
#
# ```
# X = np.linspace(0, 1, 100)
# y = 0.2 + 0.2*X + 0.02*np.random.random(100)
# ```
#
# y las herramientas desarrolladas en los apartados anteriores,
# construya un algorítmo que permita determinar una regresión lineal.
#
# 9. Compare su resultado empleando la libreria linearRegresion() de sklearn.

# %% [markdown]
# Hint:
#
# Pueden comprobar la solución de la superficie con el siguiente cálculo:
#
#
# \begin{equation}
# J(\Theta)=\frac{1}{2m} \sum_{i=1}^m ( h_{\theta} (X^{(i)})-y^{(i)})^2
# \end{equation}
#
#
#
# Sea $\Theta^T = [\theta_0,\theta_1]$
#
#
# \begin{equation}
# X =
# \begin{bmatrix}
# 1& 1 & 1 & .&.&.&1\\
# x_1^{(1)}&x_1^{(2)} & x_1^{(3)} & .&.&.&x_1^{(m)}\\
# \end{bmatrix}_{(n+1) \times m}
# \end{equation}
#
# Luego:
#
# \begin{equation}
# \Lambda = \Theta^T X=
# \begin{bmatrix}
# (\theta_0 1 + \theta_1 x_1^1)\\
# (\theta_0 1 + \theta_1 x_1^2)\\
# .\\
# .\\
# .\\
# (\theta_0 1 + \theta_1 x_1^m)\\
# \end{bmatrix}
# \end{equation}
#
#
# Sumando sobre todos los elementos de matriz se puede encontrar la función de coste $J = \mathrm{\Lambda.mean()^2}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.optimize import approx_fprime

# %% [markdown]
# ### 1) Datos

# %%
#define un data frame con los datos de entrenamiento
df = pd.DataFrame({"Y": np.arange(6), "X_1": np.arange(6)})
df
# Out:
#    Y  X_1
# 0  0    0
# 1  1    1
# 2  2    2
# 3  3    3
# 4  4    4
# 5  5    5

# %% [markdown]
# ### 2)  Función de coste

# %%
def fnc_coste(modelo, datos):
    return np.linalg.norm(modelo -datos)**2

# %% [markdown]
# ### 3)
# Asumiendo que $\theta_0=0$, represente gráficamente la función de costo para diferentes valores de $\theta_1$. Determine el valor mínimo de la función de costo y, con este valor, grafique la ecuación de regresión obtenida sobre los datos del dataframe que ha construido.

# %%
num_dat = 50
theta0 = 0
theta1 = np.linspace(-2, 4, 50)

#genera una lista de modelos para cada posible elección de theta1
modelos = [theta0 + theta1[i]*df["X_1"] for i in range(num_dat)]

#genera una lista de las evaluaciones de fnc coste para cada theta1
coste = [fnc_coste(modelos[i], df["Y"]) for i in range(num_dat)]

# Grafica la función coste
plt.plot(theta1, coste, label="J$(ϴ_1; ϴ_0 = 0)$", lw =3, alpha=0.6)
plt.title("Función de Coste") 
plt.xlabel=("$\theta_1$")
plt.legend();

# %%
#encuentra el minimo
theta_min = theta1[np.argmin(coste)]
print(f"El ϴ que minimiza el coste es: {theta_min}")
# Out:
# El ϴ que minimiza el coste es: 1.0612244897959182

# %%
#Grafica el modelo para el mejor theta1
modelo = df["X_1"]*theta_min + theta0

fig, ax = plt.subplots()

ax.plot(df["X_1"], df["Y"], label="Datos", lw =3, alpha=0.6, linestyle="", marker="o", color="maroon")
ax.plot(df["X_1"], modelo , label="modelo", lw=3, alpha=0.6, color="seagreen")
ax.grid(True)
ax.set(xlabel="x", ylabel="y")
ax.legend();

# %% [markdown]
# ### 4)
# Encontrar la función de coste para diferentes valores de $\theta_0$, $\theta_1$.
# Para ello puede emplear los metodos `surface` y `contour` dentro de la libreria de `matplotlib`.  Construya primero, con los valores de $\theta_0$, $\theta_1 $ definidos un `np.meshgrid` y evalue  para cada punto $\theta_0$, $\theta_1$ la función de coste.
#
# Para el gráfico 3D puede emplear algo similar a las siguientes lineas de código
#
# ```
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.plot_surface(t0, t1, J )
# ax.contour(t0, t1, J, 200,   linestyles="solid")
# ax.set_xlabel("$\\theta_0$")
# ax.set_ylabel("$\\theta_1$")
# plt.show()
# ```

# %%
def linear_mod(theta, datos=df):
    """
    Retorna una lista con las evaluciones del modelo sobre los datos (X_1)
    """
    num_datos= df.shape[0]
    X = np.ones((2, num_datos)) 
    X[1:,] = df["X_1"].values
    return  theta @ X

# %%
res = .1
theta0, theta1 = np.mgrid[-2:2:res, 0:2:res]
pos = np.dstack((theta0, theta1))

#evalula el costo de cada punto en la rejilla de los valores de theta0 y theta1
costo = np.zeros_like(theta0)
for i in range(pos.shape[0]):
    for j in range(pos.shape[1]):
        modelo = linear_mod(pos[i][j])
        costo[i, j] = fnc_coste(modelo, df["Y"]) 

costo = np.array(costo)
        
#grafica el costo en funcion de theta0  theta1
fig = plt.figure(figsize=(7, 8))
ax = plt.axes(111, projection = "3d")
ax.plot_surface(theta0, theta1, costo, cmap="plasma", alpha=0.7)
ax.contour(theta0, theta1, costo, 200,   linestyles="solid")
ax.set_xlabel("$\\theta_0$")
ax.set_ylabel("$\\theta_1$")
ax.set_title("J$(\\theta_0, \\theta_1)$")
plt.show()

# %% [markdown]
# ### 5)
# Encontrar la expresión teórica para la función de coste en el caso 1D y 2D

# %% [markdown]
# **Caso 1D:** se asume que $\theta_0 = 0$, por lo que el modelo de los datos corresponde a
# $$h(\theta_1, x) = \theta_1 x$$
# En concecuancia la función de coste es
# $$J(\theta_1) = \sum_{i=0}^{5} (\theta_1  x_i   - y_i )^2 = \sum_{i=0}^{5} (x_i^2 \theta^2 - 2 \theta x_i y_i + y_i ^2)$$
# reemplazando los datos que se tienen
# $$J(\theta_1) = \sum_{i=0}^5 (i^2 \theta_1^2 - 2 \theta i^2 + i^2) = (\sum_{i=0}^5 i^2)( \theta^2_1   - 2 \theta_1 + 1)$$
# Por otro lado se sabe que
# $$\sum_{k=1}^{n} k^2 = \frac{n(n+1)(2n+1)}{6}$$
# entonces
#
# $$J(\theta_1)  = 55(\theta^2_1 - 2 \theta_1 + 1)$$

# %% [markdown]
# **Caso 2D:** En este caso el modelo es
# $$h(\theta_0, \theta_1, x) = \theta_0 + \theta_1 x $$
# En consecuencia, la función de coste es
# $$J(\theta_0, \theta_1) = \sum_{i=0}^{5} ( \theta_0 + \theta_1  x_i   - y_i )^2 = \sum_{i=0}^{5} (\theta_0^2 + 2 \theta_0 \theta_1 x_i + \theta_1^2 x_i^2 - 2 \theta_0 y_i -
#  2 \theta_1 x_i y_i + y_i^2)$$
# reemplazando los datos que se tienen
# $$J(\theta_0, \theta_1)  = \sum_{i=0}^{5} (\theta_0^2 + 2 \theta_0 \theta_1 i + \theta_1^2 i^2 - 2 \theta_0 i -
#  2 \theta_1 i^2 + i^2)$$
#  $$= 5 \theta_0^2 + 2 \theta_0 \theta_1 \sum_{i=1}^{5}i + \theta_{1}^2 \sum_{i=1}^{5} i^2 - 2 \theta_0 \sum_{i=1}^{5}i - 2 \theta_1 \sum_{i=1}^{5}i^2 + \sum_{i=1}^{5}i^2$$
# Por otro lado se sabe que
# $$\sum_{k=1}^{n} k^2 = \frac{n(n+1)(2n+1)}{6}, \quad \sum_{k=1}^{5}k = \frac{n(n+1)}{2}$$
# entonces
#  $$J(\theta_0, \theta_1)= 5 \theta_0^2 + 30 (\theta_0 \theta_1)  + 55 \theta_{1}^2 - 30 \theta_0  - 110 \theta_1  + 55$$

# %% [markdown]
# ## Gradiente Desendiente

# %% [markdown]
# ### 6)
# Construya un algoritmo en el que emplee el gradiente descente para determinar el minimo de una función, determine el mínimo con una error epsilon de  1E-4, pruebe su algoritmo para $f(x)= (x-4)^2$ y al menos 3 valores de $\alpha$

# %%
#Define la función

f = lambda x: (x-4)**2
f_der = lambda x: 2*(x-4)

#Define la toleracia
tol = 1e-4

#Define la tasa de aprendizaje
alpha = 0.1

#Elige un punto inicial aleatorio entre 0 y 10
w = np.random.rand()*10

#encuentra el minimo usando gradiente desendiente
while(np.abs(f(w)) > tol):
    w = w - alpha * f_der(w)

print(f"El valor mínimo de f fue encontrado en {w}")
# Out:
# El valor mínimo de f fue encontrado en 3.990147221519461

# %% [markdown]
# ### 7)
#
# 7. Para responder este punto puede consultar la siguiente  página y seguir el video[Ejemplo guia: dotcsv](https://www.youtube.com/watch?v=-_A_AAxqzCg):
#
# Encontrar el mínimo de la siguiente función a través del metodo del gradiente descendente https://en.wikipedia.org/wiki/Gradient_descent:
#
#
# \begin{equation}
# F(x,y) = \sin \left( \frac{1}{2}x^2-\frac{1}{4}y^2 +3\right) \cos (2x+1-e^y)
# \end{equation}
#
#   -  Para ello realice una gráfica de la función en 3D, y un mapa de contorno de la función.
#   - Determine el valor mínimo de la función con el metodo del gradiente descendente.

# %%
# Define f en terminos de X[0], X[1]
f = lambda X: np.sin(X[0]**2 / 2 - X[1]**2 / 4 + 3) * np.cos(2 * X[0] + 1 - np.exp(X[1]))

# Calcula derivada parcial f  repecto a y en terminos de X[0], X[1]
f_partialx = lambda X: X[0] * np.cos(1 - np.exp(X[1]) + 2 * X[0]) * np.cos(3 + X[0]**2 / 2 - X[1]**2 / 4) - \
                       2 * np.sin(1 - np.exp(X[1]) + 2 * X[0]) * np.sin(3 + X[0]**2 / 2 - X[1]**2 / 4)

# Calcula derivada parcial f  repecto a y en terminos de X[0], X[1]
f_partialy = lambda X: -0.5 * X[1] * np.cos(1 - np.exp(X[1]) + 2 * X[0]) * np.cos(3 + X[0]**2 / 2 - X[1]**2 / 4) + \
                       np.exp(X[1]) * np.sin(1 - np.exp(X[1]) + 2 * X[0]) * np.sin(3 + X[0]**2 / 2 - X[1]**2 / 4)

# %%
#Hace la gráfica de contorno de la función
res = 100
_X = np.linspace(-2, 2, res)
_Y = np.linspace(-2, 2, res)
_Z = np.zeros((res, res))

for ix, x in enumerate(_X):
    for iy, y in enumerate(_Y):
        _Z[iy, ix] = f([x, y])
        
plt.contour(_X, _Y, _Z, 100, cmap="plasma")
plt.title("Curvas de nivel $f(x)$")
plt.colorbar()
plt.show()

# %%
#grafica el costo en funcion de theta0  theta1
fig = plt.figure()
ax = plt.axes(111, projection = "3d")
ax.plot_surface(_X, _Y, _Z, cmap="plasma")
ax.set_xlabel("$x$")
ax.set_ylabel("$y$")
ax.set_title("$f(x)$")
plt.show()

# %%
#Define la toleracia
tol = 1e-4

#Define la tasa de aprendizaje
alpha = 0.001

# Elige un mínimo estimado usando el gráfico de contorno 
W = np.ones(2)
W[0] = -1.5
W[1] = -0.5

#encuentra el minimo usando gradiente desendiente
while(np.abs(f(W)) > tol):
    f_der = approx_fprime(W, f) #Calcula la derivada usando diferencias finitas
    W = W - alpha * f_der

print(f"El valor mínimo de f fue encontrado en {W}")
# Out:
# El valor mínimo de f fue encontrado en [-1.01777208 -0.62551194]

# %% [markdown]
# ### 8)
# Empleando los siguientes datos :
#
# ```
# X = np.linspace(0, 1, 100)
# y = 0.2 + 0.2*X + 0.02*np.random.random(100)
# ```
#
# y las herramientas desarrolladas en los apartados anteriores,
# construya un algorítmo que permita determinar una regresión lineal.

# %%
#Datos
X = np.linspace(0, 1, 100)
y = 0.2 + 0.2*X + 0.02*np.random.random(100)

# %%
#Define el modelo lineal
def h(theta, datos_x=X): 
    """
    Parametros
    theta: (theta0, theta1)
    
    datos_x: Corrdenda x de los datos
    
    """
    num_datos= len(datos_x)
    X = np.ones((2, num_datos)) 
    X[1:,] = datos_x
    return  theta @ X

# %%
# Define el costo como una función J(theta)
J = lambda theta: np.linalg.norm(h(theta)  - y)**2

# %%
#Implementa gradiente desenciente para hallar el mínimo de la función coste
#Define la toleracia
tol = 1e-4

#Define la tasa de aprendizaje
alpha = 0.001

# Elige el punto inicial como 1, 1
theta = np.ones(2) 

#Para después de 1000 iteraciones
for _ in range(1000):
    J_der = approx_fprime(theta, J)
    theta = theta - alpha * J_der
    
print(f"Los parametros encontrados que minimizan el coste son \nθ_0: {theta[0]} y  θ_1: {theta[1]}")
# Out:
# Los parametros encontrados que minimizan el coste son
# θ_0: 0.20881304105921325 y  θ_1: 0.20185270807243078

# %%
# Grafica los datos
fig, ax = plt.subplots()

ax.plot(X, y, label="Datos", lw =3, alpha=0.6, linestyle="", marker="o", color="maroon")
ax.plot(X, h(theta), label="modelo", lw=3, alpha=0.6, color="seagreen")
ax.grid(True)
ax.set(xlabel="x", ylabel="y")
ax.legend();

# %% [markdown]
# ### 9)
# Compare su resultado empleando la libreria linearRegresion() de sklearn.

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X.reshape(-1,1), y.reshape(-1,1))
print(f"Los parametros encontrados con LinearREgression son \nθ_0: {reg.intercept_} y  θ_1: {reg.coef_}")
# Out:
# Los parametros encontrados con LinearREgression son
# θ_0: [0.20881327] y  θ_1: [[0.2018523]]

# %%
#Diferencia entre los parametros 
print(f"La diferencia entre los interceotps encontrados es de {np.abs(theta[0] - reg.intercept_[0])}")
print(f"La diferencia entre los coeficientes encontrados es de {np.abs(theta[1] - reg.coef_[0][0])}")
# Out:
# La diferencia entre los interceotps encontrados es de 2.2808560903864183e-07
# La diferencia entre los coeficientes encontrados es de 4.126522044345382e-07
